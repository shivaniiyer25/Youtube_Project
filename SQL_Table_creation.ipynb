# %%
import mysql.connector

# %%
mydb = mysql.connector.connect(
    host="localhost",#host_name
    user="root",#user_name
    password="Aishini@24",#user_password
    database="youtube_details"#database name
)
mycursor = mydb.cursor(buffered=True)

# %%
def table_exists(table_name):
    # Check if the table exists
    mycursor.execute("SHOW TABLES LIKE %s", (table_name,))
    return mycursor.fetchone() is not None

def create_table(table_name, create_query):
    # Create a table if it doesn't exist
    if not table_exists(table_name):
        mycursor.execute(create_query)
        print(f"Table '{table_name}' created.")

# Create channel_details table
channel_details_query = (
    "CREATE TABLE channels ("
    "channel_id VARCHAR(255), "
    "channel_name VARCHAR(255), "
    "Playlist_id VARCHAR(255), "
    "subscription_count INT, "
    "views INT, "
    "Total_videos INT, "
    "channel_description TEXT, "
    "country TEXT);"
)
create_table("channels", channel_details_query)

# Create video_details table
video_details_query = (
    "CREATE TABLE videos ("
    "channel_name VARCHAR(255), "
    "channel_id VARCHAR(255), "
    "video_id VARCHAR(255), "
    "title VARCHAR(255), "
    "thumbnail VARCHAR(255), "
    "video_description TEXT, "
    "published_date VARCHAR(255), "
    "Duration VARCHAR(255), "
    "views INT, "
    "likes INT, "
    "comments INT, "
    "favorite_count INT, "
    "Definition VARCHAR(255), "
    "Caption_status VARCHAR(255));"
)
create_table("videos", video_details_query)
def table_exists(table_name):
    # Check if the table exists
    mycursor.execute("SHOW TABLES LIKE %s", (table_name,))
    return mycursor.fetchone() is not None

def create_table(table_name, create_query):
    # Create a table if it doesn't exist
    if not table_exists(table_name):
        mycursor.execute(create_query)
        print(f"Table '{table_name}' created.")

# Create channel_details table
channel_details_query = (
    "CREATE TABLE channels ("
    "channel_id VARCHAR(255), "
    "channel_name VARCHAR(255), "
    "Playlist_id VARCHAR(255), "
    "subscription_count INT, "
    "views INT, "
    "Total_videos INT, "
    "channel_description TEXT, "
    "country TEXT);"
)
create_table("channels", channel_details_query)

# Create video_details table
video_details_query = (
    "CREATE TABLE videos ("
    "channel_name VARCHAR(255), "
    "channel_id VARCHAR(255), "
    "video_id VARCHAR(255), "
    "title VARCHAR(255), "
    "thumbnail VARCHAR(255), "
    "video_description TEXT, "
    "published_date VARCHAR(255), "
    "Duration VARCHAR(255), "
    "views INT, "
    "likes INT, "
    "comments INT, "
    "favorite_count INT, "
    "Definition VARCHAR(255), "
    "Caption_status VARCHAR(255));"
)
create_table("videos", video_details_query)


# Create comments_details table
comments_details_query = (
    "CREATE TABLE comments ("
    "comment_Id VARCHAR(255), "
    "video_Id VARCHAR(255), "
    "comment_text TEXT, "
    "comment_author VARCHAR(255), "
    "comment_posted_date VARCHAR(255), "
    "like_count INT, "
    "Reply_count INT);"
)
create_table("comments", comments_details_query)

# Close the database connection
mydb.close()
# Create comments_details table
comments_details_query = (
    "CREATE TABLE comments ("
    "comment_Id VARCHAR(255), "
    "video_Id VARCHAR(255), "
    "comment_text TEXT, "
    "comment_author VARCHAR(255), "
    "comment_posted_date VARCHAR(255), "
    "like_count INT, "
    "Reply_count INT);"
)
create_table("comments", comments_details_query)

# Close the database connection
mydb.close()
# Out:
# Table 'channels' created.
# Table 'videos' created.
# Table 'playlist' created.
# Table 'comments' created.
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\mysql\connector\cursor_cext.py:342, in CMySQLCursor.execute(self, operation, params, multi)
#     341     if not self._cnx or self._cnx.is_closed():
# --> 342         raise ProgrammingError
#     343 except (ProgrammingError, ReferenceError) as err:
#
# ProgrammingError: Unknown error
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[12], line 128
#     117 # Create comments_details table
#     118 comments_details_query = (
#     119     "CREATE TABLE comments ("
#     120     "comment_Id VARCHAR(255), "
#    (...)
#     126     "Reply_count INT);"
#     127 )
# --> 128 create_table("comments", comments_details_query)
#     130 # Close the database connection
#     131 mydb.close()
#
# Cell In[12], line 52, in create_table(table_name, create_query)
#      50 def create_table(table_name, create_query):
#      51     # Create a table if it doesn't exist
# ---> 52     if not table_exists(table_name):
#      53         mycursor.execute(create_query)
#      54         print(f"Table '{table_name}' created.")
#
# Cell In[12], line 47, in table_exists(table_name)
#      45 def table_exists(table_name):
#      46     # Check if the table exists
# ---> 47     mycursor.execute("SHOW TABLES LIKE %s", (table_name,))
#      48     return mycursor.fetchone() is not None
#
# File ~\anaconda3\lib\site-packages\mysql\connector\cursor_cext.py:344, in CMySQLCursor.execute(self, operation, params, multi)
#     342         raise ProgrammingError
#     343 except (ProgrammingError, ReferenceError) as err:
# --> 344     raise ProgrammingError("Cursor is not connected", 2055) from err
#     345 self._cnx.handle_unread_result()
#     347 stmt = b""
#
# ProgrammingError: 2055: Cursor is not connected
